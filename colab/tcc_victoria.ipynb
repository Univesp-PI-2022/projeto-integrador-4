# %%
# !pip install pysus
# Out:
# Requirement already satisfied: pysus in /usr/local/lib/python3.10/dist-packages (0.9.4)
# Requirement already satisfied: Unidecode<2.0.0,>=1.3.6 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.3.6)
# Requirement already satisfied: cffi==1.15.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.15.1)
# Requirement already satisfied: dbfread==2.0.7 in /usr/local/lib/python3.10/dist-packages (from pysus) (2.0.7)
# Requirement already satisfied: elasticsearch==7.16.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (7.16.2)
# Requirement already satisfied: fastparquet<0.9.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (0.8.3)
# Requirement already satisfied: geobr<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (0.2.0)
# Requirement already satisfied: geocoder<2.0.0,>=1.38.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.38.1)
# Requirement already satisfied: ipykernel<7.0.0,>=6.22.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (6.25.1)
# Requirement already satisfied: jupyterlab<4.0.0,>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from pysus) (3.6.5)
# Requirement already satisfied: loguru<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (0.6.0)
# Requirement already satisfied: numpy==1.23.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.23.2)
# Requirement already satisfied: pyarrow>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (13.0.0)
# Requirement already satisfied: pycparser==2.21 in /usr/local/lib/python3.10/dist-packages (from pysus) (2.21)
# Requirement already satisfied: pyreaddbc==1.0.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.0.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (2.8.2)
# Requirement already satisfied: pytz==2022.2.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (2022.2.1)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.16.0)
# Requirement already satisfied: tqdm==4.64.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (4.64.0)
# Requirement already satisfied: wget<4.0,>=3.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (3.2)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from elasticsearch==7.16.2->pysus) (1.26.16)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elasticsearch==7.16.2->pysus) (2023.7.22)
# Requirement already satisfied: pandas<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyreaddbc==1.0.0->pysus) (1.5.3)
# Requirement already satisfied: cramjam>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet<0.9.0,>=0.8.1->pysus) (2.7.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet<0.9.0,>=0.8.1->pysus) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet<0.9.0,>=0.8.1->pysus) (23.1)
# Requirement already satisfied: geopandas<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from geobr<0.3.0,>=0.2.0->pysus) (0.7.0)
# Requirement already satisfied: shapely<2.0.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from geobr<0.3.0,>=0.2.0->pysus) (1.8.5.post1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (8.1.7)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (0.18.3)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (2.31.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (1.6.6)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (0.1.6)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (1.5.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (5.7.1)
# Requirement already satisfied: jupyterlab-server~=2.19 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (2.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (1.24.0)
# Requirement already satisfied: jupyter-ydoc~=0.2.4 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.5)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.0)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (1.0.0)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (6.5.5)
# Requirement already satisfied: jinja2>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (3.1.2)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (2.0.1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (1.9.4.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (3.6.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.1->jupyterlab<4.0.0,>=3.4.5->pysus) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.22.0->pysus) (3.10.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (23.1.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (5.9.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.17.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.17.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.6.2)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.0)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.4)
# Requirement already satisfied: y-py<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-ydoc~=0.2.4->jupyterlab<4.0.0,>=3.4.5->pysus) (0.6.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.14)
# Requirement already satisfied: jsonschema>=4.17.3 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (4.19.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook<7->jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic->jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder<2.0.0,>=1.38.1->pysus) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder<2.0.0,>=1.38.1->pysus) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.2)
# Requirement already satisfied: jupyter-events>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.7.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (2.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.2.6)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /usr/local/lib/python3.10/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (0.7.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.5.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2.4)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.2.3)

# %%
from pysus.online_data.sinasc import download
from pysus.online_data import parquets_to_dataframe
from pysus.online_data import SINAN
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SINAN.list_diseases()
# Out:
# ['Animais Peçonhentos',
#  'Botulismo',
#  'Cancer',
#  'Chagas',
#  'Chikungunya',
#  'Colera',
#  'Coqueluche',
#  'Contact Communicable Disease',
#  'Acidentes de Trabalho',
#  'Dengue',
#  'Difteria',
#  'Esquistossomose',
#  'Febre Amarela',
#  'Febre Maculosa',
#  'Febre Tifoide',
#  'Hanseniase',
#  'Hantavirose',
#  'Hepatites Virais',
#  'Intoxicação Exógena',
#  'Leishmaniose Visceral',
#  'Leptospirose',
#  'Leishmaniose Tegumentar',
#  'Malaria',
#  'Meningite',
#  'Peste',
#  'Poliomielite',
#  'Raiva Humana',
#  'Sífilis Adquirida',
#  'Sífilis Congênita',
#  'Sífilis em Gestante',
#  'Tétano Acidental',
#  'Tétano Neonatal',
#  'Tuberculose',
#  'Violência Domestica',
#  'Zika']

# %%
SINAN.get_available_years('Violência Domestica')
# Out:
# ['2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022']

# %%
## Extraindo dados de 2009 a 2021
df = parquets_to_dataframe(SINAN.download('Violência Domestica', SINAN.get_available_years('Violência Domestica')[0]))

for ano in SINAN.get_available_years('Violência Domestica')[1:-1]:
  SINAN.download('Violência Domestica', ano)
  df_t = parquets_to_dataframe(SINAN.download('Violência Domestica', ano))
  df = pd.concat([df, df_t], ignore_index=True)

# %%
df.head()
# Out:
#   TP_NOT ID_AGRAVO  DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP ID_UNIDADE  \
# 0      2      Y09   2009-05-12  200919   2009        41     412550    2753278
# 1      2      Y09   2009-12-01  200948   2009        29     290270    2301687
# 2      2      Y09   2009-01-22  200903   2009        52     520870    2338262
# 3      2      Y09   2009-03-01  200909   2009        13     130356    2708930
# 4      2      Y09   2009-06-30  200926   2009        26     260290    5581923
#
#     DT_OCOR SEM_PRI  ... CONS_IDO DELEG_IDOS DIR_HUMAN MPU DELEG_CRIA  \
# 0  20090512  200919  ...
# 1  20091201  200948  ...
# 2  20090122  200903  ...
# 3  20090301  200909  ...
# 4  20090630  200926  ...
#
#   DELEG_MULH DELEG INFAN_JUV DEFEN_PUBL DT_ENCERRA
# 0                                         20090512
# 1                                         20091201
# 2                                         20090122
# 3                                         20090301
# 4                                         20090716
#
# [5 rows x 160 columns]

# %%
len(df)
# Out:
# 3035965

# %%
df.columns.to_list()
# Out:
# ['TP_NOT',
#  'ID_AGRAVO',
#  'DT_NOTIFIC',
#  'SEM_NOT',
#  'NU_ANO',
#  'SG_UF_NOT',
#  'ID_MUNICIP',
#  'ID_UNIDADE',
#  'DT_OCOR',
#  'SEM_PRI',
#  'ANO_NASC',
#  'NU_IDADE_N',
#  'CS_SEXO',
#  'CS_GESTANT',
#  'CS_RACA',
#  'CS_ESCOL_N',
#  'SG_UF',
#  'ID_MN_RESI',
#  'ID_PAIS',
#  'NDUPLIC',
#  'DT_INVEST',
#  'ID_OCUPA_N',
#  'SIT_CONJUG',
#  'DEF_TRANS',
#  'DEF_FISICA',
#  'DEF_MENTAL',
#  'DEF_VISUAL',
#  'DEF_AUDITI',
#  'TRAN_MENT',
#  'TRAN_COMP',
#  'DEF_OUT',
#  'DEF_ESPEC',
#  'SG_UF_OCOR',
#  'ID_MN_OCOR',
#  'HORA_OCOR',
#  'LOCAL_OCOR',
#  'LOCAL_ESPE',
#  'OUT_VEZES',
#  'LES_AUTOP',
#  'VIOL_FISIC',
#  'VIOL_PSICO',
#  'VIOL_TORT',
#  'VIOL_SEXU',
#  'VIOL_TRAF',
#  'VIOL_FINAN',
#  'VIOL_NEGLI',
#  'VIOL_INFAN',
#  'VIOL_LEGAL',
#  'VIOL_OUTR',
#  'VIOL_ESPEC',
#  'AG_FORCA',
#  'AG_ENFOR',
#  'AG_OBJETO',
#  'AG_CORTE',
#  'AG_QUENTE',
#  'AG_ENVEN',
#  'AG_FOGO',
#  'AG_AMEACA',
#  'AG_OUTROS',
#  'AG_ESPEC',
#  'SEX_ASSEDI',
#  'SEX_ESTUPR',
#  'SEX_PUDOR',
#  'SEX_PORNO',
#  'SEX_EXPLO',
#  'SEX_OUTRO',
#  'SEX_ESPEC',
#  'PEN_ORAL',
#  'PEN_ANAL',
#  'PEN_VAGINA',
#  'PROC_DST',
#  'PROC_HIV',
#  'PROC_HEPB',
#  'PROC_SANG',
#  'PROC_SEMEN',
#  'PROC_VAGIN',
#  'PROC_CONTR',
#  'PROC_ABORT',
#  'CONS_ABORT',
#  'CONS_GRAV',
#  'CONS_DST',
#  'CONS_SUIC',
#  'CONS_MENT',
#  'CONS_COMP',
#  'CONS_ESTRE',
#  'CONS_OUTR',
#  'CONS_ESPEC',
#  'LESAO_NAT',
#  'LESAO_ESPE',
#  'LESAO_CORP',
#  'NUM_ENVOLV',
#  'REL_SEXUAL',
#  'REL_PAI',
#  'REL_MAE',
#  'REL_PAD',
#  'REL_CONJ',
#  'REL_EXCON',
#  'REL_NAMO',
#  'REL_EXNAM',
#  'REL_FILHO',
#  'REL_DESCO',
#  'REL_IRMAO',
#  'REL_CONHEC',
#  'REL_CUIDA',
#  'REL_PATRAO',
#  'REL_INST',
#  'REL_POL',
#  'REL_PROPRI',
#  'REL_OUTROS',
#  'REL_ESPEC',
#  'AUTOR_SEXO',
#  'AUTOR_ALCO',
#  'ENC_SAUDE',
#  'ENC_TUTELA',
#  'ENC_VARA',
#  'ENC_ABRIGO',
#  'ENC_SENTIN',
#  'ENC_DEAM',
#  'ENC_DPCA',
#  'ENC_DELEG',
#  'ENC_MPU',
#  'ENC_MULHER',
#  'ENC_CREAS',
#  'ENC_IML',
#  'ENC_OUTR',
#  'ENC_ESPEC',
#  'REL_TRAB',
#  'REL_CAT',
#  'CIRC_LESAO',
#  'CLASSI_FIN',
#  'EVOLUCAO',
#  'DT_OBITO',
#  'DT_DIGITA',
#  'DT_TRANSUS',
#  'DT_TRANSDM',
#  'DT_TRANSSM',
#  'DT_TRANSRM',
#  'DT_TRANSRS',
#  'DT_TRANSSE',
#  'REL_MAD',
#  'TPUNINOT',
#  'ORIENT_SEX',
#  'IDENT_GEN',
#  'VIOL_MOTIV',
#  'CICL_VID',
#  'REDE_SAU',
#  'ASSIST_SOC',
#  'REDE_EDUCA',
#  'ATEND_MULH',
#  'CONS_TUTEL',
#  'CONS_IDO',
#  'DELEG_IDOS',
#  'DIR_HUMAN',
#  'MPU',
#  'DELEG_CRIA',
#  'DELEG_MULH',
#  'DELEG',
#  'INFAN_JUV',
#  'DEFEN_PUBL',
#  'DT_ENCERRA']

# %%
df.to_csv('violencia_2009_2021.csv')

# %% [markdown]
# ## Tratamentos a realizar
#
# - Filtrar por não duplicados
# - Filtrar por Mulher
# - Transformar nulos em nulos
# - Tranformar dados em string

# %%
df = df.loc[(df.CS_SEXO == 'F') & (df.NDUPLIC != "2") &(df.REL_PROPRI != "1")]

# %%
len(df)
# Out:
# 1700365

# %%
df = df[['TP_NOT', 'DT_NOTIFIC', 'NU_ANO', 'SG_UF_NOT', 'ID_MUNICIP', 'ID_UNIDADE', 'DT_OCOR', 'NU_IDADE_N',
         'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N', 'SG_UF', 'ID_MN_RESI', 'ID_PAIS', 'NDUPLIC',
         'ID_OCUPA_N', 'SIT_CONJUG', 'DEF_TRANS', 'SG_UF_OCOR', 'ID_MN_OCOR', 'HORA_OCOR', 'LOCAL_OCOR',
         'OUT_VEZES', 'LES_AUTOP', 'VIOL_FISIC', 'VIOL_PSICO', 'VIOL_TORT', 'VIOL_SEXU', 'VIOL_TRAF',
         'VIOL_FINAN', 'VIOL_LEGAL', 'VIOL_NEGLI', 'VIOL_INFAN', 'AG_FORCA', 'AG_ENFOR', 'AG_OBJETO',
         'AG_CORTE', 'AG_QUENTE', 'AG_ENVEN', 'AG_FOGO', 'AG_AMEACA', 'SEX_ASSEDI', 'SEX_ESTUPR', 'SEX_PUDOR',
         'SEX_EXPLO', 'SEX_PORNO', 'LESAO_NAT', 'LESAO_ESPE', 'LESAO_CORP', 'NUM_ENVOLV', 'REL_SEXUAL',
         'REL_PAI', 'REL_PAD', 'REL_MAD', 'REL_CONJ', 'REL_EXCON', 'REL_NAMO', 'REL_EXNAM', 'REL_FILHO',
         'REL_DESCO','REL_IRMAO', 'REL_CUIDA', 'REL_CONHEC', 'REL_PATRAO', 'REL_INST', 'REL_MAE', 'REL_POL',
         'AUTOR_SEXO', 'AUTOR_ALCO', 'ENC_SAUDE', 'ENC_TUTELA', 'ENC_VARA', 'ENC_ABRIGO', 'ENC_SENTIN',
         'ENC_DEAM', 'ENC_DPCA', 'ENC_DELEG', 'ENC_MPU', 'ENC_MULHER', 'ENC_CREAS', 'ENC_IML',
         'REL_TRAB', 'CLASSI_FIN', 'EVOLUCAO',
         'DT_OBITO', 'ORIENT_SEX', 'IDENT_GEN', 'VIOL_MOTIV', 'CICL_VID', 'REDE_SAU', 'ASSIST_SOC',
         'REDE_EDUCA', 'ATEND_MULH', 'DIR_HUMAN', 'MPU', 'DELEG_MULH', 'DELEG', 'DEFEN_PUBL', 'DT_ENCERRA']]

# %%
for coluna in df.columns:
    print(f'{coluna}\n{df[coluna].unique()}\n\n')
# Out:
# TP_NOT
# <StringArray>
# ['2']
# Length: 1, dtype: string
#
#
# DT_NOTIFIC
# [datetime.date(2009, 5, 12) datetime.date(2009, 12, 1)
#  datetime.date(2009, 1, 22) ... datetime.date(2021, 11, 25)
#  datetime.date(2021, 11, 26) datetime.date(2021, 11, 27)]
#
#
# NU_ANO
# <StringArray>
# ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#  '2018', '2019',     '', '2020', '2021']
# Length: 14, dtype: string
#
#
# SG_UF_NOT
# <StringArray>
# ['41', '29', '52', '13', '26', '23', '25', '42', '21', '43', '50', '27', '14',
#  '22', '35', '31', '12', '33', '15', '53', '32', '24', '51', '11', '28', '17',
#  '16']
# Length: 27, dtype: string
#
#
# ID_MUNICIP
# <StringArray>
# ['412550', '290270', '520870', '130356', '260290', '292740', '231050',
#  '291005', '250750', '230655',
#  ...
#  '432183', '430512', '421125', '353160', '250130', '420250', '220535',
#  '280470', '350340', '250390']
# Length: 5232, dtype: string
#
#
# ID_UNIDADE
# <StringArray>
# ['2753278', '2301687', '2338262', '2708930', '5581923', '0004294', '2723336',
#  '2532557', '2339528', '2593262',
#  ...
#  '2013061', '7418442', '2704919', '5864755', '2096498', '0873845', '9445900',
#  '2677539', '2363321', '0136581']
# Length: 33245, dtype: string
#
#
# DT_OCOR
# <StringArray>
# ['20090512', '20091201', '20090122', '20090301', '20090630', '20090126',
#  '20090128', '20090710', '20090202', '20090209',
#  ...
#  '20051123', '20050527', '20041010', '20030205', '19831210', '19870603',
#  '19620125', '20050120', '19980706', '20051127']
# Length: 8518, dtype: string
#
#
# NU_IDADE_N
# <StringArray>
# ['4004', '4029', '4066', '4019', '3004', '4020', '4033', '4039', '4058',
#  '4026',
#  ...
#  '1013', '1999', '4118', '4119', '3014', '1011', '2035', '1002', '  15',
#  '4121']
# Length: 205, dtype: string
#
#
# CS_SEXO
# <StringArray>
# ['F']
# Length: 1, dtype: string
#
#
# CS_GESTANT
# <StringArray>
# ['6', '5', '9', '4', '3', '1', '2', '8']
# Length: 8, dtype: string
#
#
# CS_RACA
# <StringArray>
# ['1', '2', '9', '4', '5', '', '3']
# Length: 7, dtype: string
#
#
# CS_ESCOL_N
# <StringArray>
# ['10', '06', '09', '04', '01', '03', '', '08', '02', '05', '07', '00']
# Length: 12, dtype: string
#
#
# SG_UF
# <StringArray>
# ['41', '29', '52', '13', '26', '23', '25', '42', '35', '21', '43', '50', '27',
#  '14', '22',   '', '31', '12', '33', '15', '11', '53', '32', '24', '51', '28',
#  '17', '16']
# Length: 28, dtype: string
#
#
# ID_MN_RESI
# <StringArray>
# ['412550', '292160', '522045', '130356', '260290', '520870', '520140',
#  '292740', '231050', '291005',
#  ...
#  '240390', '250840', '520120', '330090', '412555', '510788', '290050',
#  '251320', '539901', '220535']
# Length: 5580, dtype: string
#
#
# ID_PAIS
# <StringArray>
# ['1   ', '9   ', '41  ',     '', '32  ', '19  ', '12  ', '68  ', '13  ',
#  '43  ', '15  ', '7   ', '14  ', '45  ', '92  ', '18  ', '54  ', '38  ',
#  '16  ', '46  ', '37  ', '138 ', '126 ', '65  ', '137 ', '192 ', '71  ',
#  '199 ', 'BRAS', '151 ', '196 ', '153 ', 'PORT', '96  ']
# Length: 34, dtype: string
#
#
# NDUPLIC
# <StringArray>
# ['']
# Length: 1, dtype: string
#
#
# ID_OCUPA_N
# <StringArray>
# [      '', '524205', '999991', '999992', '622005', '768205', '514215',
#  '998999', '512115', '514210',
#  ...
#  '371305', '791135', '715220', '761366', '823265', '223128', '376250',
#  '632110', '203125', '722235']
# Length: 1795, dtype: string
#
#
# SIT_CONJUG
# <StringArray>
# ['8', '2', '9', '1', '', '4', '3']
# Length: 7, dtype: string
#
#
# DEF_TRANS
# <StringArray>
# ['2', '9', '1', '', '8']
# Length: 5, dtype: string
#
#
# SG_UF_OCOR
# <StringArray>
# ['41', '29', '52', '13', '26',   '', '23', '25', '42', '21', '43', '32', '50',
#  '35', '14', '22', '33', '12', '15', '11', '53', '31', '17', '24', '51', '28',
#  '27', '16']
# Length: 28, dtype: string
#
#
# ID_MN_OCOR
# <StringArray>
# ['412550', '292160', '520000', '130356', '260290', '520870', '520860',
#        '', '292950', '250750',
#  ...
#  '420285', '240390', '350470', '241080', '521565', '250840', '353700',
#  '510788', '290050', '220535']
# Length: 5639, dtype: string
#
#
# HORA_OCOR
# <StringArray>
# [     '', '09:00', '22:00', '13:15', '17:35', '12:02', '22:42', '18:30',
#  '23:00', '01:45',
#  ...
#  '02:52', '06:31', '08:19', '05:58', '04:48', '04:18', '00000', '06:52',
#  '05:26', '05:36']
# Length: 1442, dtype: string
#
#
# LOCAL_OCOR
# <StringArray>
# ['01', '07', '99', '09', '06', '', '03', '02', '05', '04', '08', '2 ']
# Length: 12, dtype: string
#
#
# OUT_VEZES
# <StringArray>
# ['2', '9', '1', '', '0']
# Length: 5, dtype: string
#
#
# LES_AUTOP
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# VIOL_FISIC
# <StringArray>
# ['1', '2', '', '9']
# Length: 4, dtype: string
#
#
# VIOL_PSICO
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# VIOL_TORT
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# VIOL_SEXU
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# VIOL_TRAF
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# VIOL_FINAN
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# VIOL_LEGAL
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# VIOL_NEGLI
# <StringArray>
# ['1', '2', '9', '']
# Length: 4, dtype: string
#
#
# VIOL_INFAN
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# AG_FORCA
# <StringArray>
# ['1', '2', '9', '']
# Length: 4, dtype: string
#
#
# AG_ENFOR
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# AG_OBJETO
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# AG_CORTE
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# AG_QUENTE
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# AG_ENVEN
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# AG_FOGO
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# AG_AMEACA
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# SEX_ASSEDI
# <StringArray>
# ['8', '1', '2', '', '9', 'M', 'F']
# Length: 7, dtype: string
#
#
# SEX_ESTUPR
# <StringArray>
# ['8', '1', '', '2', '9']
# Length: 5, dtype: string
#
#
# SEX_PUDOR
# <StringArray>
# ['8', '2', '1', '', '9']
# Length: 5, dtype: string
#
#
# SEX_EXPLO
# <StringArray>
# ['8', '1', '2', '', '9']
# Length: 5, dtype: string
#
#
# SEX_PORNO
# <StringArray>
# ['8', '2', '1', '', '9']
# Length: 5, dtype: string
#
#
# LESAO_NAT
# <StringArray>
# ['04', '11', '08', '02', '01', '07', '10', '99',   '', '06', '09', '88', '05',
#  '03']
# Length: 14, dtype: string
#
#
# LESAO_ESPE
# <StringArray>
# [                              '', 'VAGINAL                       ',
#  'FRATURA                       ', 'POLITRAUMATISMO               ',
#  'FRATURA/CONTUSAO              ', 'FRATURA/TRAUMATISMO DENTARIO  ',
#  'ESCORIACOES                   ', 'PAF                           ',
#  'CORTE/PERFURACAO              ', 'TRAUMA VAGINAL                ',
#  ...
#  'DOR GENERALIZADA              ', 'TRAUMA POS OPERATORIO         ',
#  'LESAO DE PELE + MIASE         ', 'DESNUTRICAO TARDIA            ',
#  'TRAUM.DENTARIO C AVULSAO DE DE', 'PETEQUIAS EM VULVA            ',
#  'CUNHADA                       ', 'FALTA DE ACOMP.               ',
#  'FEZES                         ', 'ESCORIACAO EM PESCOCO E TRONCO']
# Length: 9007, dtype: string
#
#
# LESAO_CORP
# <StringArray>
# ['01', '10', '05', '08', '11',   '', '03', '09', '88', '06', '04', '02', '99',
#  '07']
# Length: 14, dtype: string
#
#
# NUM_ENVOLV
# <StringArray>
# ['1', '9', '2', '', '3']
# Length: 5, dtype: string
#
#
# REL_SEXUAL
# <StringArray>
# ['8', '1', '9', '', '2', '3']
# Length: 6, dtype: string
#
#
# REL_PAI
# <StringArray>
# ['2', '9', '', '1', '.']
# Length: 5, dtype: string
#
#
# REL_PAD
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# REL_MAD
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_CONJ
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# REL_EXCON
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_NAMO
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_EXNAM
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_FILHO
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_DESCO
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# REL_IRMAO
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_CUIDA
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_CONHEC
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_PATRAO
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_INST
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_MAE
# <StringArray>
# ['1', '2', '9', '']
# Length: 4, dtype: string
#
#
# REL_POL
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# AUTOR_SEXO
# <StringArray>
# ['2', '1', '9', '', '3']
# Length: 5, dtype: string
#
#
# AUTOR_ALCO
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# ENC_SAUDE
# <StringArray>
# ['2', '1', '', '9', '8']
# Length: 5, dtype: string
#
#
# ENC_TUTELA
# <StringArray>
# ['1', '2', '9', '']
# Length: 4, dtype: string
#
#
# ENC_VARA
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# ENC_ABRIGO
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# ENC_SENTIN
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# ENC_DEAM
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# ENC_DPCA
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# ENC_DELEG
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# ENC_MPU
# <StringArray>
# ['2', '9', '1', '']
# Length: 4, dtype: string
#
#
# ENC_MULHER
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# ENC_CREAS
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# ENC_IML
# <StringArray>
# ['2', '9', '', '1']
# Length: 4, dtype: string
#
#
# REL_TRAB
# <StringArray>
# ['2', '1', '9', '']
# Length: 4, dtype: string
#
#
# CLASSI_FIN
# <StringArray>
# ['1', '8', '', '3', '2']
# Length: 5, dtype: string
#
#
# EVOLUCAO
# <StringArray>
# ['9', '1', '', '3', '2', '4']
# Length: 6, dtype: string
#
#
# DT_OBITO
# <StringArray>
# [        '', '20090308', '20090409', '20091218', '20090419', '20090710',
#  '20090727', '20091026', '20090920', '20091109',
#  ...
#  '20140212', '20140214', '20140216', '20140222', '20140313', '20140219',
#  '20140221', '20140220', '20140223', '20150402']
# Length: 1374, dtype: string
#
#
# ORIENT_SEX
# <StringArray>
# ['', '2', '9', '1', '8', '3']
# Length: 6, dtype: string
#
#
# IDENT_GEN
# <StringArray>
# ['', '9', '8', '2', '3', '1']
# Length: 6, dtype: string
#
#
# VIOL_MOTIV
# <StringArray>
# [  '', '99', '09', '88', '06', '01', '04', '02', '07', '03', '08', '05', '9 ',
#  '1 ', '6 ', '7 ', '8 ', '2 ', '3 ', '4 ', '5 ']
# Length: 21, dtype: string
#
#
# CICL_VID
# <StringArray>
# ['', '9', '3', '4', '1', '2', '5']
# Length: 7, dtype: string
#
#
# REDE_SAU
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# ASSIST_SOC
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# REDE_EDUCA
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# ATEND_MULH
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# DIR_HUMAN
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# MPU
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# DELEG_MULH
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# DELEG
# <StringArray>
# ['', '1', '9', '2']
# Length: 4, dtype: string
#
#
# DEFEN_PUBL
# <StringArray>
# ['', '2', '9', '1']
# Length: 4, dtype: string
#
#
# DT_ENCERRA
# <StringArray>
# ['20090512', '20091201', '20090122', '20090301', '20090716', '20090126',
#  '20090128', '20090710', '20090202', '20090209',
#  ...
#  '20220507', '20220508', '20220514', '20220515', '20220525', '20220528',
#  '20220529', '20221120', '20221114', '20221127']
# Length: 5126, dtype: string

# %%
df.replace('', np.nan, inplace=True)

# %%
pd.set_option('display.max_rows', None)
df.isna().mean()*100
# Out:
# TP_NOT          0.000000
# DT_NOTIFIC      0.000000
# NU_ANO          0.002134
# SG_UF_NOT       0.000000
# ID_MUNICIP      0.000000
# ID_UNIDADE      0.152049
# DT_OCOR         0.644377
# NU_IDADE_N      0.073798
# CS_SEXO         0.000000
# CS_GESTANT      0.000000
# CS_RACA         1.153033
# CS_ESCOL_N      5.699065
# SG_UF           0.014194
# ID_MN_RESI      0.014194
# ID_PAIS         0.343108
# NDUPLIC       100.000000
# ID_OCUPA_N     53.281491
# SIT_CONJUG      2.478941
# DEF_TRANS       1.620359
# SG_UF_OCOR      2.381858
# ID_MN_OCOR      3.348192
# HORA_OCOR      43.437993
# LOCAL_OCOR      1.208045
# OUT_VEZES       1.842310
# LES_AUTOP       2.209075
# VIOL_FISIC      1.710902
# VIOL_PSICO      3.212980
# VIOL_TORT       4.006531
# VIOL_SEXU       3.696170
# VIOL_TRAF       4.074021
# VIOL_FINAN      4.036264
# VIOL_LEGAL      4.085617
# AG_FORCA        3.106945
# AG_ENFOR        4.779069
# AG_OBJETO       4.813255
# AG_CORTE        4.635880
# AG_QUENTE       4.860985
# AG_ENVEN        4.587732
# AG_FOGO         4.835844
# AG_AMEACA       4.405486
# SEX_ASSEDI      4.112335
# SEX_ESTUPR      4.054864
# SEX_PUDOR      71.823571
# SEX_EXPLO       4.229039
# LESAO_NAT      77.926137
# LESAO_ESPE     97.323738
# LESAO_CORP     77.775015
# NUM_ENVOLV      2.086990
# REL_SEXUAL     77.524723
# REL_PAI         4.684955
# REL_PAD         4.859593
# REL_CONJ        4.253530
# REL_EXCON       4.642420
# REL_NAMO        4.823645
# REL_EXNAM       4.858851
# REL_FILHO       4.858526
# REL_DESCO       4.675399
# REL_IRMAO       4.898881
# REL_CONHEC      4.621918
# REL_PATRAO      4.940535
# REL_INST        4.972169
# REL_POL         4.914049
# AUTOR_SEXO      1.514045
# AUTOR_ALCO      2.044826
# ENC_SAUDE      78.569586
# ENC_ABRIGO     80.327616
# ENC_SENTIN     80.297466
# ENC_DEAM       79.759031
# ENC_DPCA       80.297651
# ENC_DELEG      79.845400
# ENC_MPU        80.325343
# ENC_MULHER     80.214854
# ENC_CREAS      80.218194
# ENC_IML        80.185307
# REL_TRAB        2.818107
# CLASSI_FIN     76.751443
# EVOLUCAO       78.043258
# DT_OBITO       99.817151
# ORIENT_SEX     24.083483
# IDENT_GEN      24.108995
# VIOL_MOTIV     24.076294
# CICL_VID       23.987884
# REDE_SAU       24.310212
# ASSIST_SOC     24.936314
# REDE_EDUCA     24.963170
# ATEND_MULH     24.947678
# DIR_HUMAN      24.972262
# MPU            24.969757
# DELEG_MULH     24.901479
# DELEG          24.922584
# DEFEN_PUBL     24.967067
# DT_ENCERRA      1.397202
# dtype: float64
