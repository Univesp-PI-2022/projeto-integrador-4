# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
# Ler o arquivo CSV
df = pd.read_csv('https://raw.githubusercontent.com/Univesp-PI-2022/projeto-integrador-4/main/dados/censo1.csv',sep=";")

# Exibir o DataFrame resultante
df.head()
# Out:
#    ID Situação de rua Onde dormiu ontem Tempo de permanência       Sexo  \
# 0   1             Rua     Não se aplica        Não se aplica   Feminino
# 1   2        Acolhido               Rua        Não se aplica  Masculino
# 2   3             Rua     Não se aplica        Não se aplica   Feminino
# 3   4             Rua     Não se aplica        Não se aplica  Masculino
# 4   5             Rua     Não se aplica        Não se aplica   Feminino
#
#   Identifica com o sexo nasceu          Idade  Faixa de idade  \
# 0                Não respondeu  Não respondeu  Sem informação
# 1              Homem Cisgênero             38         31 a 49
# 2             Mulher Cisgênero             27         18 a 30
# 3              Homem Cisgênero             15         12 a 17
# 4             Mulher Cisgênero  Não respondeu  Sem informação
#
#   Classificação de idade     Cor_Raça_Etnia  ...           Tempo na situação  \
# 0         Sem informação  Sem identificação  ...                       NR/NS
# 1                 Adulto              Parda  ...             Mais de 10 anos
# 2              Juventude              Parda  ...   Mais de 2 anos até 5 anos
# 3            Adolescente             Branca  ...  Mais de 5 anos até 10 anos
# 4         Sem informação  Sem identificação  ...                       NR/NS
#
#       Tipo de ponto Presença_Moradia_Improvisada Criança_acomp_Adulto  \
# 0             Praça                          Não                  Não
# 1     Não se aplica                Não se aplica        Não se aplica
# 2             Praça                          Sim                  Não
# 3           Calçada                          Sim                  Não
# 4  Canteiro central                          Sim                  Não
#
#   Criança_Sozinha           Latitude          Longitude      Data  \
# 0             Não  -23,4962781999999         -46,391831  10/25/21
# 1   Não se aplica        -23,5225168         -46,522712  10/25/21
# 2             Não        -23,5232932        -46,6549845   11/3/21
# 3             Não  -23,7430783949666  -46,6929477602377  10/27/21
# 4             Não        -23,5251419        -46,6255225   11/9/21
#
#        Subprefeitura        Distrito
# 0     Itaim Paulista  Itaim Paulista
# 1              Penha           Penha
# 2                 Sé   Santa Cecília
# 3  Capela do Socorro          Grajaú
# 4              Mooca            Pari
#
# [5 rows x 21 columns]

# %%
df.count()
# Out:
# ID                              31884
# Situação de rua                 31884
# Onde dormiu ontem               31884
# Tempo de permanência            31884
# Sexo                            31884
# Identifica com o sexo nasceu    31884
# Idade                           31884
# Faixa de idade                  31884
# Classificação de idade          31884
# Cor_Raça_Etnia                  31884
# Parentes no CA                  31884
# Tempo na situação               31884
# Tipo de ponto                   31884
# Presença_Moradia_Improvisada    31884
# Criança_acomp_Adulto            31884
# Criança_Sozinha                 31884
# Latitude                        31717
# Longitude                       31717
# Data                            31884
# Subprefeitura                   31884
# Distrito                        31884
# dtype: int64

# %% [markdown]
# ### Mostrando os lugares ###

# %%
df[['Latitude', 'Longitude']].head()
# Out:
#             Latitude          Longitude
# 0  -23,4962781999999         -46,391831
# 1        -23,5225168         -46,522712
# 2        -23,5232932        -46,6549845
# 3  -23,7430783949666  -46,6929477602377
# 4        -23,5251419        -46,6255225

# %%
df['Latitude'] = df['Latitude'].apply(lambda x: float(str(x).replace(',', '.')))
df['Longitude'] = df['Longitude'].apply(lambda x: float(str(x).replace(',', '.')))

# %%
df[['Latitude', 'Longitude']].head()
# Out:
#     Latitude  Longitude
# 0 -23.496278 -46.391831
# 1 -23.522517 -46.522712
# 2 -23.523293 -46.654984
# 3 -23.743078 -46.692948
# 4 -23.525142 -46.625523

# %%
df['Latitude'].count()
# Out:
# 31717

# %%
df['Longitude'].count()
# Out:
# 31717

# %% [markdown]
# ### Removendo Nan ###

# %%
df.dropna(subset=['Latitude'], inplace=True)

# %%
df.dropna(subset=['Longitude'], inplace=True)

# %%
df.count()
# Out:
# ID                              31717
# Situação de rua                 31717
# Onde dormiu ontem               31717
# Tempo de permanência            31717
# Sexo                            31717
# Identifica com o sexo nasceu    31717
# Idade                           31717
# Faixa de idade                  31717
# Classificação de idade          31717
# Cor_Raça_Etnia                  31717
# Parentes no CA                  31717
# Tempo na situação               31717
# Tipo de ponto                   31717
# Presença_Moradia_Improvisada    31717
# Criança_acomp_Adulto            31717
# Criança_Sozinha                 31717
# Latitude                        31717
# Longitude                       31717
# Data                            31717
# Subprefeitura                   31717
# Distrito                        31717
# dtype: int64

# %%
df['Latitude'].isna().sum()
# Out:
# 0

# %%
df['Longitude'].isna().sum()
# Out:
# 0

# %%
df = df.sample(n=100, random_state=42)

# %%
df.count()
# Out:
# ID                              100
# Situação de rua                 100
# Onde dormiu ontem               100
# Tempo de permanência            100
# Sexo                            100
# Identifica com o sexo nasceu    100
# Idade                           100
# Faixa de idade                  100
# Classificação de idade          100
# Cor_Raça_Etnia                  100
# Parentes no CA                  100
# Tempo na situação               100
# Tipo de ponto                   100
# Presença_Moradia_Improvisada    100
# Criança_acomp_Adulto            100
# Criança_Sozinha                 100
# Latitude                        100
# Longitude                       100
# Data                            100
# Subprefeitura                   100
# Distrito                        100
# dtype: int64

# %%
mapa = folium.Map(location=[-23,-46], zoom_start=13)

# %%
# Adicionar marcadores para cada lugar no dataset
for index, row in df.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']]).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3898f5ece219429c451e85054cde7df7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3898f5ece219429c451e85054cde7df7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3898f5ece219429c451e85054cde7df7 = L.map(
#                 &quot;map_3898f5ece219429c451e85054cde7df7&quot;,
#                 {
#                     center: [-23.0, -46.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6822b091d8e460a683557aeef265e6d6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_0ae0b0e47528362ff143c2558d8770a9 = L.marker(
#                 [-23.627176, -46.738046],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_67ad152b9a432a6ff463310031b734cb = L.marker(
#                 [-23.5107518, -46.6183535],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_0f87511efe0575fc5eb4f5c316f4e543 = L.marker(
#                 [-23.563061, -46.645435],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_a82331b3d24e7fe1bd6a4088a6b499c1 = L.marker(
#                 [-23.5492397, -46.6419316],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_ed435e43095491d37e2bf4960e3d7173 = L.marker(
#                 [-23.6451134530434, -46.7334191194333],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_f20c123e2cdeae4d7bdb46f550b73341 = L.marker(
#                 [-23.5402257, -46.6266968],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_f1bbbf2f6401f478c20216b3218e330f = L.marker(
#                 [-23.5187109128634, -46.5962361298413],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_dec5e6f20c0c0399e49e076362f53e27 = L.marker(
#                 [-23.6042584, -46.6356457],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_0499ea7d9d237e855e420c91c0bfedc6 = L.marker(
#                 [-23.5177728, -46.7004536],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_7bb80cbcfaa9991fef8dc874f0232ed6 = L.marker(
#                 [-23.5499236, -46.6117782],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_ad9a1f965c52d7f52e82a544ded495dc = L.marker(
#                 [-23.5218099, -46.5339956],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_593bfdaf6b85bbb9bb337314a0c96303 = L.marker(
#                 [-23.5333441908895, -46.6430457917207],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_c3aeecfc2a5566c535d1d92b042b0c93 = L.marker(
#                 [-23.6048599, -46.5552932],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_24cc71de747e45eb42b9d83b4aa94faa = L.marker(
#                 [-23.5382962, -46.5634669],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_91f16f360c15401c2ca75d06a2235f0b = L.marker(
#                 [-23.5629323, -46.6451491],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_a63ba87626365d1e00d92015ac3f6154 = L.marker(
#                 [-23.6174067, -46.6437206],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_1754e7df5ff0850c1df15e1ddbbe8388 = L.marker(
#                 [-23.5340121067753, -46.6441369243178],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_fb81053befb14ec86d539a2400020c3a = L.marker(
#                 [-23.5334718519278, -46.643180963496],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_68a41b7b60331ea25229b6c74816c675 = L.marker(
#                 [-23.5097414, -46.6235127],
#                 {}
#             ).addTo(map_3898f5ece219429c451e85054cde7df7);
#
#
#             var marker_427450c78469121ed2a62d8ee5fdb4d1 = L.marker(
#                 [-23.5220409, -46.6374847],
#                 {}
#             ).addTo(map_3898f5
